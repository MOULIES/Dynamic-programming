# %% [markdown]
# https://www.youtube.com/watch?v=ZqG89Z-dKpI&list=PLEJXowNB4kPxBwaXtRO1qFLpCzF75DYrS&index=22

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def longestRepeatingSubsequence( s1 , s2 ):
    dp = [ [0]*(len(s2)+1)  for _ in range( len(s1)+1)]
    
    for i in range( 1, len(s1)+1):
        for j in range( 1, len(s2)+1):
            if i != j and s1[i] == s2[j]:
                dp[i][j] =  1+ dp[i-1][j-1]
            else:
                dp[i][j] = max( dp[i][j-1], dp[i-1][j] )
    return dp[-1][-1]

# %%
def longestRepeatingSubsequence( s1 , s2 ):
    dp = [ ['']*(len(s2)+1)  for _ in range( len(s1)+1)]
    
    for i in range( 1, len(s1)+1):
        for j in range( 1, len(s2)+1):
            if i != j and s1[i-1] == s2[j-1]:
                dp[i][j] =  dp[i-1][j-1]+ s1[i-1]
            else:
                dp[i][j] = dp[i][j-1] if len(dp[i][j-1]) > len(dp[i-1][j] ) else dp[i-1][j]
    return dp[-1][-1]

# %%
s1 ='aabb'
longestRepeatingSubsequence( s1 , s1 )
# Out:
# 'ab'

# %% [markdown]
# Time complexity = O(N ^ 2)
